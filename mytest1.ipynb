# %%
import numpy as np
import sympy as sp
import os
from queue import PriorityQueue
import matplotlib.pyplot as plt
import cv2
import pygame
import math
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.7.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Declaring map

# %%
#node size ratio (unit/node)

def map():
    global x_size, y_size, map_def, Rat
    Rat=0.5
    x_size = int(400/Rat) #x and y  as per gloabl coordinate system and not matrix
    y_size = int(250/Rat)
    map_def = np.zeros((y_size,x_size,360))
    map_def[:,:,:] = -2

# %% [markdown]
# Declaring Node

# %%
class Node:
    def __init__(self, node_id, node_loc, parent_id, c2c , c2g):
        self.parent_id = parent_id #
        self.node_id = node_id #unique node id for each node
        self.node_loc = node_loc ## [x,y,angle]
        self.c2c= round(c2c,0)
        self.c2g=round(c2g,2)
        self.total_cost = round(c2c+c2g,2)

# %% [markdown]
# Declaring Obstacle space

# %%
"""Circle"""

#x is column and y is row for the matrix
def circle_obs():
    global x_c, y_c, x_nc, y_nc, map_obs1, allp_map,x_centre,y_centre,radius
    x_c = []
    y_c = []
    x_nc = []
    y_nc = []
    y_centre = int((249 - 65)/Rat)
    x_centre = int((399 - 100)/Rat)
    radius_c = int(55/Rat) #radius of circle including clearance
    radius = int(40/Rat)
    map_obs1 = np.copy(map_def) # a deep copy #change this to map_obs1
    for x in range(int(240/Rat),int(360/Rat)):
        for y in range(int(120/Rat), int(240/Rat)):
            if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius_c:
                map_obs1[y, x,:] = -1 #obstacle space updated as -1
                x_c.append(x) #to be used for plotting
                y_c.append(y)
                allp_map.append([x,y]) #to be used for visualisation on pygame
            if (np.sqrt((x-x_centre)**2 + (y-y_centre)**2)) < radius:
                x_nc.append(x) #list of obstacle without clearance
                y_nc.append(y)

# %%
"""Triangles"""

def triang_obs():
    global x_t1, y_t1, x_t1_nc, y_t1_nc, map_obs2, x_t2_nc, y_t2_nc, x_t2, y_t2, allp_map, Rat
    x_t1 = []
    y_t1 = []
    x_t2 = []
    y_t2 = []
    x_t1_nc = []
    y_t1_nc = []
    x_t2_nc = []
    y_t2_nc = []
    map_obs2 = np.copy(map_obs1)
    for x in range(int(170/Rat)):
        for y in range(int(40*Rat),int(240/Rat)):
            if (y - (6/7)*x - ((779/7) + 15)/Rat)<=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (-16/5)*x - ((2169/5) +25)/Rat)<=0 :
                map_obs2[y,x,:] = -1
                x_t1.append(x)
                y_t1.append(y)
                allp_map.append([x,y])
            if (y - (6/7)*x - ((779/7))/Rat)<=0 and (y - (-85/69)*x - ((15880/69))/Rat)>=0 and (y - (-16/5)*x - ((2169/5) +10)/Rat)<=0 :
                map_obs2[y,x,:] = -1
                x_t1_nc.append(x)
                y_t1_nc.append(y)
                allp_map.append([x,y])
            if (y - (6/7)*x - ((779/7) - 15)/Rat)>=0 and (y - (-85/69)*x - ((15880/69) -18)/Rat)>=0 and (y - (25/79)*x - ((13661/79) +15)/Rat)<=0:
                map_obs2[y,x,:] = -1
                x_t2.append(x)
                y_t2.append(y)
                allp_map.append([x,y])
            if (y - (6/7)*x - ((779/7) )/Rat)>=0 and (y - (-85/69)*x - ((15880/69))/Rat)>=0 and (y - (25/79)*x - ((13661/79))/Rat)<=0:
                map_obs2[y,x,:] = -1
                x_t2_nc.append(x)
                y_t2_nc.append(y)
                allp_map.append([x,y])

# %%
"""Hexagon"""

def hex_obs():
    global map_obs4, x_h, y_h, x_h_nc, y_h_nc, allp_map
    x_h = []
    y_h = []
    x_h_nc = []
    y_h_nc = []
    map_obs4 = np.copy(map_obs2)
    for x in range(int(148/Rat), int(252/Rat)):
        for y in range(int(30/Rat),int(165/Rat)):
            if (y - (5/8)*x + 81/Rat)>=0 and (y + (5/8)*x - 281/Rat)<=0 and (y - (5/8)*x - 31/Rat)<=0 and (y + (5/8)*x - 169/Rat)>=0 and (x - 249/Rat)<=0 and (x - 150/Rat)>=0:
                map_obs4[y,x,:] = -1
                x_h.append(x)
                y_h.append(y)
                allp_map.append([x,y])
            if (y - (4/7)*x + (380/7)/Rat)>=0 and (y + (4/7)*x - 1780/7/Rat)<=0 and (y - (4/7)*x - (180/7)/Rat)<=0 and (y + (4/7)*x - (1220/7)/Rat)>=0 and (x - 234/Rat)<=0 and (x - 165/Rat)>=0:
                map_obs4[y,x,:] = -1
                x_h_nc.append(x)
                y_h_nc.append(y)
                allp_map.append([x,y])

# %%
def c2g(initial, final):
    return np.round(np.linalg.norm(np.array(initial)-np.array(final)),2)

# %%
"""considering a radius of 1.5 for goal space:"""

def goal_space(goal_x, goal_y):
    centre_x = goal_x
    centre_y = goal_y
    goal_list = []
    for i in range(goal_x-int(30/Rat),goal_x+int(30/Rat)):
        for j in range(goal_y-int(30/Rat), goal_y+int(30/Rat)):
            if ((i-centre_x)**2 + (j-centre_y)**2)<=(15/Rat):
                goal_list.append([i,j])
    return goal_list

# %%
def pop(Closed_list, Open_list, All_list): ### pop from open list and add to closed list and check for goal
    dat = Open_list.get()
    #dat[0] is c2c+c2g, dat[1] is Node_id--> starts from 1, list starts from 0 
    Closed_list.append(All_list[dat[1]-1]) #indexing the node from the all_list  
    
    print('closed list updated')

    ##check for goal
    if All_list[dat[1]-1].node_loc[0:2] in goal_list:
        goal_id=dat[1]-1
        print('this will be done at', All_list[dat[1]-1].node_loc )
        print('the goal cost is', All_list[dat[1]-1].total_cost)
        return "Goal found", goal_id
    return 1, All_list[dat[1]-1]

# %%
def movement(node, All_list, Open_list, rpm1, rpm2):
    ##8 actions

    ##move right with rpm1
    move_zero(node, All_list, Open_list,[0,rpm1])
    print('moving right rpm1')
    ## move left with rpm1
    move_zero(node, All_list, Open_list,[rpm1,0])
    print('moving left rpm1')
    ## move straight with rpm1
    move_zero(node, All_list, Open_list,[rpm1,rpm1])
    print('moving straight rpm1')
    ## move right with rpm2
    move_zero(node, All_list, Open_list,[0,rpm2])
    print('moving right rpm2')
    ## move left with rpm2
    move_zero(node, All_list, Open_list,[rpm2,0])
    print('moving left rpm2')
    ## move straight with rpm2
    move_zero(node, All_list, Open_list,[rpm2,rpm2])
    print('moving straight rpm2')
    ## move right if rpm2>rpm1
    move_zero(node, All_list, Open_list,[rpm1,rpm2])
    print('moving s1 rpm2')
    ## move left if rpm2>rpm1
    move_zero(node, All_list, Open_list,[rpm2,rpm1])
    print('moving s2 rpm2')

# %%
def move_zero(node, All_list, Open_list,action):
    ## r= radius of wheel
    ## L= wheel distance
    r = 0.038
    L = 0.354
    ul=action[0]
    ur=action[1]
    t=0
    dt=0.1
    D=0
    Xn,Yn,thetan=node.node_loc
    thetan=3.14*thetan/180 ## degree to radian
    while t<0.2:
        Xs=Xn
        Ys=Yn
        t=t+dt
        d_xn=(0.5*r * (ul+ur) * math.cos(thetan) * dt)/Rat
        d_yn=(0.5*r * (ul+ur) * math.sin(thetan) * dt)/Rat
        d_theta=((r / L) * (ur-ul) * dt)
        Xn=Xn+d_xn
        Yn=Yn+d_yn
        thetan+= d_theta
        D=D+math.sqrt(math.pow((0.5*r * (ul+ur) * math.cos(thetan) * dt),2)+math.pow((0.5*r * (ul+ur) * math.sin(thetan) * dt),2))
        ## check if path in obstacle
        # print(Xn,Yn,thetan)
        if map_obs4[int(np.round(Yn)),int(np.round(Xn)),int(np.round((thetan*180/3.14))%360)]==-1:
            print('Path in obstacle')
            return None
    Xn=int(np.round(Xn))
    Yn=int(np.round(Yn))
    thetan=int(np.round((180*(thetan)/3.14))%360)
    if map_obs4[Yn,Xn,thetan]==-2:
        param(All_list, Open_list, map_obs4, Xn,Yn,thetan,D, node)
        print('node created')
        return None
    else:
        print('node exists, cost check')
        cost_update(node, Xn ,Yn,thetan, All_list,  Closed_list, Open_list, map_obs4, D)  
        return None

# %%
def param(All_list, Open_list, map_obs4, Xn, Yn, thetan,D, node):
     id = All_list[-1].node_id + 1
     map_obs4[Yn,Xn,thetan] = id  ## id is updated in map
     c2_g=c2g([Xn,Yn],goal_location[0:2])
     c2c=node.c2c+D
     cost = c2c+c2_g  #cost_dir is a dictionary
     parent = node.node_id
     loc = [Xn,Yn,thetan]
     print('node at id', id, 'cost is', cost, 'loc', loc)
     All_list.append(Node(id, loc, parent, c2c,c2_g)) ## node is created
     tup_new = [cost, id]
     Open_list.put(tup_new) ## list of [cost, id] ###gives the [cost,id] in priority queue open list

# %%
def cost_update(nod, Xn ,Yn, thetan, All_list,  Closed_list, Open_list, map_obs4, D):
     index = int(map_obs4[Yn, Xn, thetan])
     if round((nod.c2c + D),1)< round(All_list[index-1].c2c,1): #since index/node_id is starting from 1
            All_list[index-1].c2c = round((nod.c2c + D),1)
            All_list[index-1].parent_id = nod.node_id
            print('updated cost of node', index, 'is', All_list[index-1].total_cost)
            if Open_list.qsize() > 0:
                for j in Open_list.queue:
                    if j[1] ==index:
                            j[0] = round((nod.c2c + D),1)
                            # i.parent_id = nod.node_id

# %%
def initial():
    global All_list, Closed_list, goal_location, Open_list, allp_map, goal_list, L,rpm1,rpm2,Rat
    allp_map = []
    All_list = []
    Closed_list = []
    goal_list = []
    first_node_id = 1
    start_cords_x = int(10)   ##int(input("please enter the starting x coordinate between 10 and 390: \n"))
    start_cords_y = int(10)     ##int(input("please enter the starting y coordinate between 10 and 240: \n"))
    start_angle= int(0)    ##int(input("please enter the starting angle from 0 to 330 (step size of 30 degree: \n"))
    Rat=0.5
    rpm1=50
    rpm2=100
    r = 0.038
    L = 0.354
    goal_cords_x = 100   ##int(input("please enter the goal x coordinate between 10 and 390: \n"))
    goal_cords_y = 100      ##int(input("please enter the goal y coordinate between 10 and 240: \n"))
                            ##int(input("please enter the goal angle from 0 to 330 (step size of 30 degree: \n"))
    goal_list = goal_space(int((goal_cords_x-1)/Rat), int((goal_cords_y-1)/Rat))

    # if start_cords_x<10 or start_cords_x>(400-10) or start_cords_y<10 or start_cords_y>(250-10):
    #     print("Either wrong input or the start node is in obstacle space")
    #     exit(0)
    # else:
    start_location = [int((start_cords_x-1)/Rat), int((start_cords_y-1)/Rat), start_angle]
    
    
    
    # if goal_cords_x<10 or goal_cords_x>(400-10) or goal_cords_y<10 or goal_cords_y>(250-10):
    #     print("Either wrong input or the goal node is in obstacle space")
    #     exit(0)
    # else:
    goal_location = [int((goal_cords_x-1)/Rat), (int(goal_cords_y-1)/Rat)]
    #                                                            ##int(input("Enter the value of step size between (1-10): \n"))



    ### Initialising map
    map()
    print('map is defined, initialising obstacle space')
    circle_obs()
    triang_obs()
    hex_obs()
    # if map_obs4[int((start_cords_x-1)/Rat), int((start_cords_y-1)/Rat), start_angle]==-1 or map_obs4[int((goal_cords_y-1)/Rat), int((goal_cords_x-1)/Rat), goal_k]==-1:
    #     print("start or goal node in obstacle space")
    #     exit(0)
    # else:
    map_obs4[int((start_cords_y-1)/Rat), int((start_cords_x-1)/Rat), start_angle] = first_node_id
    first_parent_id = 0
    initial_c2g=c2g(start_location[0:2], goal_location[0:2])
    first_cost = 0+initial_c2g
    All_list.append(Node(first_node_id, start_location, first_parent_id,0,initial_c2g))
    tup = [first_cost, first_node_id] # just the cost and node id, access the node using all visited and node id
    Open_list = PriorityQueue()
    Open_list.put(tup)

# %%
Rat=0.5
initial()
# Out:
# map is defined, initialising obstacle space

# %%
##goal_cost = np.inf
while(1):
    if (Open_list.qsize()>0):
        print('inside while')
        r,node =pop(Closed_list, Open_list, All_list) ## pop works
        print('all list length is', len(All_list))
        if type(r) == str:
            print('done/GOAL FOUND')
            goal_id=node
            # display_path(goal_id)
            # display()
            break
        else:
            print('popped')
            movement(node, All_list, Open_list, rpm1,rpm2)
    else:
        print('open list empty')
        break
# Out:
# inside while
# closed list updated
# all list length is 1
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 9
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 17
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 25
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 33
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 41
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 49
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 57
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 65
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 73
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 81
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 89
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 97
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 105
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 113
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 121
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 129
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 137
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 145
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 153
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 161
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 169
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 177
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 185
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 193
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 201
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 209
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 217
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 225
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 233
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 241
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 249
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 257
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 265
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 273
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 281
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 289
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 297
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 305
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 313
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 321
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 329
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 337
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 345
# popped
# node exists, cost check
# updated cost of node 304 is 245.96
# moving right rpm1
# node exists, cost check
# updated cost of node 305 is 245.96
# moving left rpm1
# node exists, cost check
# updated cost of node 303 is 245.64
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 308 is 245.77
# moving straight rpm2
# node exists, cost check
# updated cost of node 306 is 246.07
# moving s1 rpm2
# node exists, cost check
# updated cost of node 307 is 246.07
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 347
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 355
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 363
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 353 is 245.28
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 370
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 361 is 247.01
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 377
# popped
# node exists, cost check
# updated cost of node 312 is 245.96
# moving right rpm1
# node exists, cost check
# updated cost of node 313 is 245.96
# moving left rpm1
# node exists, cost check
# updated cost of node 311 is 245.65
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 316 is 245.78
# moving straight rpm2
# node exists, cost check
# updated cost of node 314 is 246.08
# moving s1 rpm2
# node exists, cost check
# updated cost of node 315 is 246.08
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 379
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 355 is 244.59
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 386
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 354 is 245.09
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 369 is 245.6
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 390
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 398
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 386 is 243.73
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 398 is 244.09
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 402
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 386 is 243.73
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 409
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 417
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 409 is 242.86
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 417 is 243.22
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 421
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 409 is 242.86
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 428
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 436
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 428 is 242.0
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 436 is 242.36
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 440
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 428 is 242.0
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 447
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 455
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 447 is 241.14
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 460
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 468
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 476
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 484
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 492
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 500
# popped
# node exists, cost check
# updated cost of node 467 is 240.62
# moving right rpm1
# node exists, cost check
# updated cost of node 468 is 240.62
# moving left rpm1
# node exists, cost check
# updated cost of node 466 is 240.32
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 471 is 240.44
# moving straight rpm2
# node exists, cost check
# updated cost of node 469 is 240.75
# moving s1 rpm2
# node exists, cost check
# updated cost of node 470 is 240.75
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 502
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 510
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 510 is 239.26
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 517
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 509 is 239.76
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 508 is 239.95
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 522
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 530
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 517 is 238.39
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 530 is 238.76
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 534
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 541
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 517 is 238.39
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 548
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 548 is 237.53
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 553
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 559
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 548 is 237.53
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 566
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 574
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 566 is 236.66
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 574 is 237.03
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 578
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 566 is 236.66
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 585
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 593
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 585 is 235.8
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 593 is 236.16
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 597
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 604
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 585 is 235.8
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 611
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 619
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 611 is 234.94
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 619 is 235.3
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 623
# popped
# node exists, cost check
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 628
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 635
# popped
# node exists, cost check
# updated cost of node 320 is 245.97
# moving right rpm1
# node exists, cost check
# updated cost of node 321 is 245.97
# moving left rpm1
# node exists, cost check
# updated cost of node 319 is 245.67
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 324 is 245.81
# moving straight rpm2
# node exists, cost check
# updated cost of node 322 is 246.1
# moving s1 rpm2
# node exists, cost check
# updated cost of node 323 is 246.1
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 637
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 611 is 234.94
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 644
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node exists, cost check
# updated cost of node 627 is 235.43
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 651
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 644 is 234.08
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 651 is 234.43
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 655
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# updated cost of node 603 is 235.79
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 659
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 666
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node exists, cost check
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 668
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node exists, cost check
# updated cost of node 363 is 246.82
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 672
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 675
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# updated cost of node 626 is 235.12
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 677
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 684
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 688
# popped
# node exists, cost check
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 693
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 700
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 707
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 714
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 721
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 729
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 736
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 744
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 750
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 757
# popped
# node exists, cost check
# updated cost of node 706 is 234.2
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 716 is 233.64
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 763
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 771
# popped
# node exists, cost check
# updated cost of node 713 is 234.2
# moving right rpm1
# node exists, cost check
# updated cost of node 714 is 234.2
# moving left rpm1
# node exists, cost check
# updated cost of node 712 is 233.89
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 724 is 234.02
# moving straight rpm2
# node exists, cost check
# updated cost of node 722 is 234.32
# moving s1 rpm2
# node exists, cost check
# updated cost of node 723 is 234.32
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 773
# popped
# node exists, cost check
# moving right rpm1
# node exists, cost check
# updated cost of node 370 is 245.09
# moving left rpm1
# node exists, cost check
# updated cost of node 384 is 244.42
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 778
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 786
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 794
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 802
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 810
# popped
# node exists, cost check
# updated cost of node 785 is 233.47
# moving right rpm1
# node exists, cost check
# updated cost of node 786 is 233.47
# moving left rpm1
# node exists, cost check
# updated cost of node 784 is 233.16
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 789 is 233.3
# moving straight rpm2
# node exists, cost check
# updated cost of node 787 is 233.59
# moving s1 rpm2
# node exists, cost check
# updated cost of node 788 is 233.59
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 812
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 820
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 827
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 835
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 843
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 851
# popped
# node exists, cost check
# updated cost of node 834 is 232.1
# moving right rpm1
# node exists, cost check
# updated cost of node 835 is 232.1
# moving left rpm1
# node exists, cost check
# updated cost of node 833 is 231.8
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 838 is 231.94
# moving straight rpm2
# node exists, cost check
# updated cost of node 836 is 232.23
# moving s1 rpm2
# node exists, cost check
# updated cost of node 837 is 232.23
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 853
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 861
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 866
# popped
# node exists, cost check
# updated cost of node 842 is 232.13
# moving right rpm1
# node exists, cost check
# updated cost of node 843 is 232.13
# moving left rpm1
# node exists, cost check
# updated cost of node 841 is 231.83
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 846 is 231.97
# moving straight rpm2
# node exists, cost check
# updated cost of node 844 is 232.26
# moving s1 rpm2
# node exists, cost check
# updated cost of node 845 is 232.26
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 868
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 876
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node exists, cost check
# updated cost of node 792 is 233.19
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 882
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 889
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 794 is 233.49
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 893
# popped
# node exists, cost check
# updated cost of node 885 is 231.24
# moving right rpm1
# node exists, cost check
# updated cost of node 861 is 231.23
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 899
# popped
# node exists, cost check
# updated cost of node 884 is 231.24
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 889 is 230.94
# moving straight rpm1
# node exists, cost check
# updated cost of node 874 is 231.93
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 873 is 231.06
# moving straight rpm2
# node exists, cost check
# updated cost of node 887 is 231.13
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 902
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 876 is 231.25
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 909
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 917
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node exists, cost check
# ...
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# updated cost of node 7599 is 177.25
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7669 is 178.11
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7934
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7940
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 7896 is 175.79
# moving straight rpm1
# node exists, cost check
# updated cost of node 7822 is 177.61
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 7855 is 176.9
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7767 is 176.9
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7943
# popped
# node exists, cost check
# moving right rpm1
# node exists, cost check
# updated cost of node 7246 is 178.46
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# updated cost of node 7242 is 178.27
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7228 is 179.32
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7945
# popped
# node exists, cost check
# updated cost of node 7896 is 175.79
# moving right rpm1
# node exists, cost check
# updated cost of node 7808 is 177.41
# moving left rpm1
# node exists, cost check
# updated cost of node 7767 is 176.9
# moving straight rpm1
# node exists, cost check
# updated cost of node 7531 is 177.7
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node exists, cost check
# updated cost of node 7855 is 176.9
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7761 is 177.09
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7946
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 7906 is 175.89
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7953
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7959
# popped
# node created
# moving right rpm1
# node exists, cost check
# updated cost of node 7580 is 175.92
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7680 is 175.83
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7964
# popped
# node exists, cost check
# updated cost of node 7943 is 175.99
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 7885 is 174.93
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# updated cost of node 7922 is 175.55
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7968
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# updated cost of node 7825 is 177.64
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7970
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7976
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7981
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7988
# popped
# node exists, cost check
# moving right rpm1
# node exists, cost check
# updated cost of node 3840 is 204.71
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7993
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 7926 is 175.07
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 7997
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8004
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 7899 is 177.59
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8008
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 7959 is 176.21
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8012
# popped
# node exists, cost check
# updated cost of node 7918 is 176.58
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 7983 is 176.03
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8018
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# updated cost of node 7864 is 177.06
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8025
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8032
# popped
# node exists, cost check
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 3963 is 203.87
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8035
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# updated cost of node 7953 is 175.05
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8040
# popped
# node exists, cost check
# updated cost of node 7909 is 176.15
# moving right rpm1
# node exists, cost check
# updated cost of node 7311 is 177.96
# moving left rpm1
# node exists, cost check
# updated cost of node 7769 is 177.65
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7745 is 178.46
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8043
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 7858 is 176.78
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7743 is 177.4
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8047
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8050
# popped
# node created
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8055
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 8017 is 175.7
# moving straight rpm1
# node exists, cost check
# updated cost of node 8024 is 177.06
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8059
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node exists, cost check
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8065
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node created
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node created
# moving straight rpm2
# node created
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8072
# popped
# node exists, cost check
# moving right rpm1
# node created
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 8004 is 177.14
# moving straight rpm2
# node exists, cost check
# moving s1 rpm2
# node created
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8076
# popped
# node created
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# updated cost of node 7960 is 175.53
# moving straight rpm1
# node created
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# updated cost of node 7964 is 175.42
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7961 is 175.23
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8080
# popped
# node exists, cost check
# updated cost of node 8047 is 175.48
# moving right rpm1
# node exists, cost check
# moving left rpm1
# node exists, cost check
# moving straight rpm1
# node exists, cost check
# updated cost of node 7702 is 176.44
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7912 is 175.72
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8082
# popped
# node exists, cost check
# updated cost of node 7942 is 176.16
# moving right rpm1
# node exists, cost check
# updated cost of node 7768 is 177.96
# moving left rpm1
# node created
# moving straight rpm1
# node exists, cost check
# updated cost of node 7945 is 177.22
# moving right rpm2
# node created
# moving left rpm2
# node exists, cost check
# moving straight rpm2
# node created
# moving s1 rpm2
# node exists, cost check
# updated cost of node 7944 is 177.52
# moving s2 rpm2
# inside while
# closed list updated
# all list length is 8085
# popped
# node exists, cost check
# updated cost of node 7818 is 176.93
# moving right rpm1
# node created
# moving left rpm1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5238/686250195.py in <module>
#      13         else:
#      14             print('popped')
# ---> 15             movement(node, All_list, Open_list, rpm1,rpm2)
#      16     else:
#      17         print('open list empty')
#
# /tmp/ipykernel_5238/2569298344.py in movement(node, All_list, Open_list, rpm1, rpm2)
#       9     print('moving left rpm1')
#      10     ## move straight with rpm1
# ---> 11     move_zero(node, All_list, Open_list,[rpm1,rpm1])
#      12     print('moving straight rpm1')
#      13     ## move right with rpm2
#
# /tmp/ipykernel_5238/3968604531.py in move_zero(node, All_list, Open_list, action)
#      24         ## check if path in obstacle
#      25         # print(Xn,Yn,thetan)
# ---> 26         if map_obs4[int(np.round(Yn)),int(np.round(Xn)),int(np.round((thetan*180/3.14))%360)]==-1:
#      27             print('Path in obstacle')
#      28             return None
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3737     around : equivalent function; see for details.
#    3738     """
# -> 3739     return around(a, decimals=decimals, out=out)
#    3740
#    3741
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3312
#    3313     """
# -> 3314     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3315
#    3316
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      41     except AttributeError:
#      42         wrap = None
# ---> 43     result = getattr(asarray(obj), method)(*args, **kwds)
#      44     if wrap:
#      45         if not isinstance(result, mu.ndarray):
#
# KeyboardInterrupt:

# %%
#creating an empty canvas
canvas = np.zeros((int(250/Rat),int(400/Rat),3),np.uint8)

#list of all obstacles to put in canvas
for c in allp_map: #change the name of the variable l
    x = c[1]
    y = c[0]
    canvas[(x,y)]=[0,255,255] #assigning a yellow coloured pixel
canvas = np.flipud(canvas)
canvas_for_backtrack = canvas.copy()
canvas_for_visited = canvas.copy()
canvas_for_visited = cv2.resize(canvas_for_visited,(1200,750))
#showing the obstacle map
cv2.imshow('canvas',canvas)
cv2.waitKey(0)
cv2.destroyAllWindows()

pygame.init()

display_width = int(400/Rat)
display_height = int(250/Rat)
display_h = 250
n = 2
m = n
s = n/Rat
# gameDisplay = pygame.display.set_mode((display_width,display_height),0, 32, 0, 10)
gameDisplay = pygame.display.set_mode((n*display_width,n*display_height))
# gameDisplay = pygame.display.set_mode((1920,1080),flags, vsync =1)
# gameDisplay = pygame.display.set_mode((0,0),pygame.FULLSCREEN)
pygame.display.set_caption('Visited Nodes- Animation')
black = (0,0,0)
white = (255,255,255)
Y = (255, 0,0)
B = (0,255,0)
# surf = pygame.surfarray.make_surface(canvas_for_visited)

clock = pygame.time.Clock()
done = True
while done:
    for event in pygame.event.get():  
        if event.type == pygame.QUIT:  
            done = False  
    
    gameDisplay.fill(black)
    pygame.draw.circle(gameDisplay, B, (n*x_centre, n*(display_height-1-y_centre)), n*radius)
    pygame.draw.polygon(gameDisplay, B, [(s*114,s*(display_h-1-209)),(s*35,s*(display_h-1-184)), (s*104,s*(display_h-1-99)), (s*79,s*(display_h-1-179))])
    pygame.draw.polygon(gameDisplay, B, [(s*199,s*(display_h-1-59.6)),(s*234,s*(display_h-1-78.8)), (s*234,s*(display_h-1-119)), (s*200,s*(display_h-1-139)),(s*164,s*(display_h-1-119)),(s*164,s*(display_h-1-78.8))])
    for i in range(len(All_list)):
            p_id = All_list[i].parent_id
            if(i>0):
                x_start = All_list[p_id -1].node_loc[0]
                y1_start = All_list[p_id -1].node_loc[1]
                y_start = abs(display_height-1-y1_start)
                # print(x_start, y_start)
            else:
                x_start = All_list[p_id].node_loc[0]
                y1_start = All_list[p_id].node_loc[1]
                y_start = abs(display_height-1-y1_start)
            
            x = All_list[i].node_loc[0]
            y1 = All_list[i].node_loc[1]
            y = abs(display_height-1-y1)
            pygame.draw.line(gameDisplay, white, (n*x_start,n*y_start),(m*x,m*y), 1)
            pygame.display.flip()
            # pygame.time.wait(4)

    # ind = int(map_obs4[All_list[goal_id].node_loc[0], All_list[goal_id].node_loc[1],All_list[goal_id].node_loc[2]])
    # for i in range(len(x_a)-1):
    #         pygame.draw.line(gameDisplay, Y, (n*x_a[i],n*(display_height-y_a[i])),(n*x_a[i+1],n*(display_height-y_a[i+1])), 5)
    #         pygame.display.flip()
            # pygame.time.wait(4)
    done = False
    
    pygame.time.wait(4000)
    pygame.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5238/1504991792.py in <module>
#      62             y = abs(display_height-1-y1)
#      63             pygame.draw.line(gameDisplay, white, (n*x_start,n*y_start),(m*x,m*y), 1)
# ---> 64             pygame.display.flip()
#      65             # pygame.time.wait(4)
#      66
#
# KeyboardInterrupt:

# %%
map_obs4[360,250]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4585/3585599592.py in <module>
# ----> 1 map_obs4[360,250]
#
# NameError: name 'map_obs4' is not defined

# %%
import numpy as np
Xn = 401
np.round(Xn)>=400
# Out:
# True
